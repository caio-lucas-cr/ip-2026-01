# %% [markdown]
# <a href="https://colab.research.google.com/github/caio-lucas-cr/ip-2026-01/blob/main/Lista_1_20_Quest%C3%B4es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão 1:
#
# Algoritmo "Aprovado ou Reprovado"
#
# Var
#
#    nota1, nota2, nota3, media: real
#
#
# Inicio
#
#       //Entrada
#       escreva ("Digite suas nota: ")
#       leia(nota1)
#
#       escreva ("Digite suas nota: ")
#       leia(nota2)
#
#       escreva ("Digite suas nota: ")
#       leia(nota3)
#
#
#       //Processamento
#       media <- (nota1 + nota2 + nota3)/3
#
#       escreval("A média do aluno é: ", media)
#
#       //Saída
#       se media >= 7 entao
#          escreva("Aprovado")
#       senao
#          escreva (“Reprovado")
#       fimse
#
# Fimalgoritmo

# %% [markdown]
# Questão 2:
#
# Algoritmo "Arrecadação de jogos"
#
# Var
#
#    ingressos: inteiro
#    perc_popular, perc_geral, perc_arquibancadas, perc_cadeiras, renda: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite a quantidade de ingressos: ")
#       leia(ingressos)
#
#       escreva ("Digite o percentagem de pessoas na categoria popular: ")
#       leia (perc_popular)
#
#       escreva ("Digite o percentagem de pessoas na categoria geral: ")
#       leia (perc_geral)
#
#       escreva ("Digite o percentagem de pessoas na categoria arquibancadas: ")
#       leia (perc_arquibancadas)
#
#       escreva ("Digite o percentagem de pessoas na categoria cadeiras: ")
#       leia (perc_cadeiras)
#
#
#       //Processamento
#       renda <- (perc_popular*1 + perc_geral*5 + perc_arquibancadas*10 + perc_cadeiras*20)*ingressos/100
#
#       //Saída
#
#       escreval ("A renda do jogo é: ", renda)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 3:
#
# Algoritmo "Composição Inteira"
#
# Var
#
#    n1, n2, n3, N, Q: inteiro
#
#
# Inicio
#
#       //Entrada
#
#       escreva ("Digite o número 1: ")
#       leia (n1)
#
#       escreva ("Digite o número 2: ")
#       leia (n2)
#
#       escreva ("Digite o número 3: ")
#       leia (n3)
#
#       //Processamento
#
#       N <- n1*100 + n2*10 + n3
#       Q <- N*N
#
#       //Saída
#       se (n1 <= 0) ou (n1 > 9) ou (n2 < 0) ou (n3 > 9) ou (n3 < 0) ou (n3 > 9) então
#          escreval("Digíto inválido")
#       senao
#          escreval("O número e o seu quadrado são respectivamente: ", N, ",",Q)
#       fimse
#
# Fimalgoritmo

# %% [markdown]
# Questão 4:
#
# Algoritmo "Consumo de energia"
#
# Var
#
#    salario, kW, val_kW, val_cons, val_desc: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o valor do salário mínimo: ")
#       leia(salario)
#
#       escreva("Digite a quantidade de kW consumido por residência: ")
#       leia(kW)
#
#       //Processamento
#       val_kW <- salario*0.007
#       val_cons <- val_kW*kW
#       val_desc <- val_cons*0.9
#
#       //Saída
#       escreval("Custo por kW: R$ ", val_kw)
#       escreval("Custo do consumo: R$ ", val_cons)
#       escreval("Custo com desconto: R$ ", val_desc)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 5:
#
# Algoritmo "Conta de água"
#
# Var
#
#    u: inteiro
#
#    cons_mc, v: real
#
#    categoria: caracter
#
#
# Inicio
#
#       //Entrada
#       escreva("Digite a conta do cliente: ")
#       leia(u)
#
#       escreva("Digite o consumo de água por metros cúbicos: ")
#       leia(cons_mc)
#
#       escreva("Digite o tipo de consumidor: ")
#       leia(categoria)
#
#       //Processamento
#       se (categoria = "R") entao
#          v <- 5 + 0.05*cons_mc
#       senao
#            se (categoria = "C") entao
#               se cons_mc <= 80 entao
#                  v <- 500
#               senao
#                    v <- 500 + 0.25*(cons_mc - 80)
#               fimse
#            senao
#                 se (categoria = "I") entao
#                    se cons_mc <= 100 entao
#                       v <- 800
#                    senao
#                       v <- 800 + 0.04*(cons_mc - 100)
#                    fimse
#                 fimse
#            fimse
#       fimse
#
#       //Saída
#       escreval("Conta: ", u)
#       escreval("Valor da conta: ", v)
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 6:
#
# Algoritmo "Conversão de temperatura"
#
# Var
#
#    f1, f2, f3, c1, c2, c3: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite a primeira temperatura em Fahrenheit: ")
#       leia(f1)
#
#       escreva("Digite a segunda temperatura em Fahrenheit: ")
#       leia(f2)
#
#       escreva("Digite a terceira temperatura em Fahrenheit: ")
#       leia(f3)
#
#       //Processamento
#       c1 <- 5*(f1 - 32)/9
#       c2 <- 5*(f2 - 32)/9
#       c3 <- 5*(f3 - 32)/9
#
#       //Saída
#       escreval(f1, " ", "FAHRENHEIT EQUIVALE A", c1, " ", "CELSIUS")
#       escreval(f2, " ", "FAHRENHEIT EQUIVALE A", c2, " ", "CELSIUS")
#       escreval(f3, " ", "FAHRENHEIT EQUIVALE A", c3, " ", "CELSIUS")
#
# Fimalgoritmo

# %% [markdown]
# Questão 7:
#
# Algoritmo "Conversões para o Sistema Métrico"
#
# Var
#
#    f, c, p, m: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite a temperatura em Fahrenheit: ")
#       leia(f)
#
#       escreva("Digite a quantidade de chuva em polegada: ")
#       leia(p)
#
#       //Preocessamento
#       c <- 5*(f-32)/9
#       m <- 25.4*p
#
#       //Saída
#       escreval("O valor em celsius: ", c)
#       escreval("A quantidade de chuva E: ", m)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 8:
#
# Algoritmo "Custo da Lata de Cerveja"
#
# Var
#
#    r, a, custo_lata: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o valor do raio: ")
#       leia(r)
#
#       escreva("DIgite o valor da altura: ")
#       leia(a)
#
#       //Processamento
#       custo_lata <- 100*(2*(3.14159*(r^2)) + 2*3.14159*r*a)
#
#       //Saída
#       escreval("O VALOR DO CUSTO E = ", custo_lata)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 9:
#
# Algoritmo "Equação do Delta na Equação de Báskara"
#
# Var
#
#    A, B, C, delta: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o coeficiente A: ")
#       leia(A)
#
#       escreva("Digite o coeficiente B: ")
#       leia(B)
#
#       escreva("Digite o coeficiente C: ")
#       leia(C)
#
#       //Processamento
#       delta <- B^2 - 4*A*C
#
#       //Saída
#       escreval("O VALOR DE DELTA E: ", delta)
#
# Fimalgoritmo

# %% [markdown]
# Quetão 10:
#
# Algoritmo "Cálculo do Determinante de uma Matriz Quadrada de Duas Dimensões"
#
# Var
#
#    a, b, c, d, Det: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o valor de a: ")
#       leia(a)
#
#       escreva("Digite o valor de b: ")
#       leia(b)
#
#       escreva("Digite o valor de c: ")
#       leia(c)
#
#       escreva("Digite o valor de d: ")
#       leia(d)
#
#       //Processamento
#       Det <- (a*d)-(c*b)
#
#       //Saída
#       escreval("O VALOR DO DETERMINANTE E: ", Det)
#
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 11:
#
# Algoritmo "Divísivel de 3 e 5"
#
# Var
#
#    N: inteiro
#
# Inicio
#
#       //Entrada
#       escreva("Digite o número inteiro: ")
#       leia(N)
#
#       //Saída
#       se (N % 3 = 0) e (N % 5 = 0) entao
#          escreval("O NUMERO E DIVISIVEL")
#       senao
#            escreval("O NUMERO NAO E DIVISIVEL")
#       fimse
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 12:
#
# Algoritmo "Locadora de charretes"
#
# Var
#
#    h, x: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite a quantidade de horas que utilizou a charrete: ")
#       leia(h)
#
#       //Processamento
#       x <- (h \ 3)*10 + (h % 3)*5
#
#       //Saída
#       escreval("O VALOR A PAGAR E: ", x)
#
# Fimalgoritmo

# %% [markdown]
# Questão 13:
#
# Algoritmo "Conversão de Nota em Conceito"
#
# Var
#
#    nota: real
#    conceito: caracter
#
# Inicio
#
#       //Entrada
#       escreva("Digite a nota: ")
#       leia(nota)
#
#       //Processamento
#       se (nota >= 9.0) e (nota <= 10.0) entao
#          conceito <- "A"
#       senao
#            se (nota >= 7.5) e (nota < 9.0) entao
#               conceito <- "B"
#            senao
#                 se (nota >= 6.0) e (nota < 7.5) entao
#                    conceito <- "C"
#                 senao
#                    conceito <- "D"
#                 fimse
#            fimse
#       fimse
#
#       //Saída
#       escreval("NOTA = ",nota, " ", "CONCEITO = ", conceito)
#
# Fimalgoritmo

# %% [markdown]
# Questão 14:
#
# Algoritmo "Volume da Pirâmide de Base Hexagonal"
#
# Var
#
#    v, Ab, a, h: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite a altura da pirâmide: ")
#       leia(h)
#
#       escreva("Digite a aresta do hexágono: ")
#       leia(a)
#
#       //Processamento
#       Ab <- 3*(a^2)*(3^(1/2))/2
#       v <- (1/3)*Ab*h
#
#       //Saída
#       escreval("O VOLUME DA PIRÂMIDE E: ", v, " ", "METROS CUBICOS")
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 15:
#
# Algoritmo "Quadrado de pares"
#
# Var
#
#    N, x: inteiro
#
# Inicio
#
#       //Entrada
#       escreva("Digite um número: ")
#       leia(N)
#
#       //Saída
#       para x de 1 ate N faca
#       se (x % 2 = 0) e (x > 5) e ( x < 2000) entao
#       escreval(x, "^2 = ", x*x)
#       fimse
#       fimpara
#
# Fimalgoritmo

# %% [markdown]
# Questão 16:
#
# Algoritmo "Reajuste salarial"
#
# Var
#
#    salario, reaj_sal: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o valor do salário: ")
#       leia(salario)
#
#       //Processamento
#       se (salario <= 300) entao
#          reaj_sal <- salario*1.5
#       senao
#            reaj_sal <- salario*1.3
#       fimse
#
#       //Saída
#       escreval("SALARIO COM REAJUSTE: ", reaj_sal)
#
# Fimalgoritmo

# %% [markdown]
# Questão 17:
#
# Algoritmo "Série de pares"
#
# Var
#
#    x, y, k: inteiro
#
# Inicio
#
#       //Entrada
#       escreva(" Digite dois números inteiros: ")
#       leia(x,y)
#
#       //Saída
#       se (x % 2 = 0) entao
#          para k de 1 ate y faca
#          escreva(x, " ")
#          x <- x + 2
#          fimpara
#       senao
#            escreval("O PRIMEIRO NÚMERO NÃO É PAR")
#       fimse
#
# Fimalgoritmo

# %% [markdown]
# Questão 18:
#
# Algoritmo "Soma de progressão aritmética"
#
# Var
#
#    a1, r, N, x: inteiro
#    S: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite o número incial da PA, a razão e a quantidade de termos: ", " ", " ")
#       leia(a1,r,N)
#
#       //Processamento
#       S <- (a1 + (a1 + (N-1)*r))*N/2
#
#       //Saída
#       escreval("A SOMA É: ", S)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 19:
#
# Algoritmo "Somatório Simples"
#
# Var
#
#    n, k: inteiro
#    S: real
#
# Inicio
#
#       //Entrada
#       escreva("Digite um número inteiro: ")
#       leia(n)
#
#       //Saída
#       se (n > 1) entao
#          S <- 0
#          para k de 1 ate n faca
#               S <- S + (1/k)
#          fimpara
#       senao
#       escreval("Número inválido")
#       fimse
#
#       escreval("A soma é: ", S)
#
# Fimalgoritmo

# %% [markdown]
# Questão 20:
#
# Algoritmo "Tempo em segundos"
#
# Var
#
#    h, min, s, seg: inteiro
#
# Inicio
#
#       //Entrada
#       escreva("Digite as horas, minutos e segundos: ")
#       leia(h, min, s)
#
#       //Processamento
#       seg <- h*60*60 + min*60 + s
#
#       //Saída
#       escreval("A quantidade de segundos é: ",seg)
#
#
# Fimalgoritmo
